# %% [markdown]
# ## Import des données que l'on veut visualiser

# %%
import pandas as pd
import mysql.connector as mc
from sqlalchemy import create_engine

engine = create_engine('mysql+mysqlconnector://root:root@localhost:3306/laferme', echo = False)

cnx = mc.connect(
  host="localhost",
  auth_plugin='mysql_native_password',
  user="samir",
  passwd="admin",
  database='laferme'
)

# %%
production = pd.read_sql(sql='SELECT * FROM productionviande',  con=cnx)
production
# Out:
#     fkelevage  annee  quantite
# 0           3     15     32596
# 1           5     15     39176
# 2           6     15     17057
# 3           9     15     31034
# 4          15     15     28637
# 5          24     15     29141
# 6          27     15     24200
# 7          30     15     17907
# 8          46     15     31799
# 9          52     15     32341
# 10         62     15     30978
# 11         66     15     18268
# 12         67     15     28325
# 13         68     15     20470
# 14         69     15     18055
# 15         72     15     35430
# 16         76     15     21416
# 17         78     15     24698
# 18         90     15     29643
# 19         97     15     39923
# 20         99     15     28540
# 21          8     16     17285
# 22          9     16     10385
# 23         12     16     16034
# 24         16     16     24937
# 25         20     16     36988
# 26         25     16     32105
# 27         29     16     21385
# 28         32     16     25176
# ...

# %%
rendement=pd.read_sql('select idelevage,nom,sum(productionviande.quantite/elevage.capacite) as rendement from productionviande,elevage,animal where idanimal=fkanimal and idelevage=fkelevage group by elevage.idelevage', con=cnx)
rendement.set_index('idelevage')
# Out:
#                       nom  rendement
# idelevage
# 3                  chevre    20.0221
# 5          vache laitiere   183.9249
# 6                  canard     6.7048
# 9                  chevre    26.9791
# 15                 chevre    13.1968
# 24                 chevre    15.2491
# 27                  dinde    19.5129
# 30         vache laitiere   277.9903
# 46                 chevre    20.0498
# 52                  dinde    11.1945
# 62                 chevre    15.5903
# 66                 chevre    12.5467
# 67                 mouton    28.5247
# 68         vache laitiere   411.3153
# 69                 canard     7.6961
# 72                 chevre    19.5100
# 76                 canard     7.2572
# 78                  dinde    10.4035
# 90                  dinde    18.1549
# 97                 chevre    30.5322
# 99                   porc   154.7610
# 8                   dinde    11.7505
# 12                 canard     7.2225
# 16                 mouton    35.5135
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
