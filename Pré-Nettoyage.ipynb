# %%
import pandas as pd

# %%
pluie= pd.read_csv("pluie.csv", sep=',')
pluie
# Out:
#       saison  annee terrain  precipitation
# 0    automne     16      34           79.0
# 1    automne     15      17          105.0
# 2    automne     16      42         1520.0
# 3    automne     99      16           18.0
# 4    automne     15      30         2140.0
# 5    automne     16       2           88.0
# 6    automne     18       3           27.0
# 7    automne     18      28           30.0
# 8    automne     15      45          162.0
# 9    automne     56      42          149.0
# 10   automne     15      46           95.0
# 11   automne     18      49           58.0
# 12   automne     17      15          203.0
# 13   automne     15      23         1740.0
# 14   automne     15       4          113.0
# 15   automne     17      16           25.0
# 16   automne     15      12          105.0
# 17   automne     17      47          112.0
# 18   automne     16       6           85.0
# 19   automne     16      10          101.0
# 20   automne     16       8           52.0
# ...

# %%
temperature = pd.read_csv('temperature.csv',encoding = "utf-8",sep = ';|,', engine='python')
temperature
# Out:
#       date  mini  terrain  maxi  moyenne
# 0    01/14    -4       13    40       29
# 1    01/15   -11       11    33       15
# 2    01/15    -7       28    40       20
# 3    01/15    -1       33    18       18
# 4    01/17   -11       38    29       28
# 5    01/15    -9       38    36       29
# 6    01/15   -11       56    38       13
# 7    01/15    -7       58    41       24
# 8    01/15    -2       99    31       14
# 9    01/16   -12        6    26       21
# 10   01/16   -14       30    38       20
# 11   01/16   -13       44    28       18
# 12   01/16   -14       75    45       13
# 13   01/16     1       98    25       24
# 14   01/17    -2       28    25       24
# 15   01/17    -2       65    42       17
# 16   01/17     0       65    29       23
# 17   01/17    -1       79    26       29
# 18   01/18   -12       20    32       16
# 19   01/19   -13       19    44       17
# 20   01/19     0       20    33       23
# 21   01/19   -12       28    35       22
# ...
